# %% [markdown]
# <a href="https://colab.research.google.com/github/aavinashverma42-dev/Python/blob/main/platform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # popular platform to learn Python Systematically

# %%
import webbrowser

#  // W3Shools
webbrowser.open = "https://www.w3schools.com/python/default.asp"

# // GeekForGeeks
webbrowser.open = "https://www.geeksforgeeks.org/python/introduction-to-python/"

# %% [markdown]
# # For Problem Solving and Practice

# %%
import webbrowser

#  // Hacker Rank
webbrowser.open = "https://www.hackerrank.com/domains/python"

# // Leetcode
webbrowser.open = "https://leetcode.com/problemset/all-code-essentials/"
