# %% [markdown]
# <a href="https://colab.research.google.com/github/aavinashverma42-dev/Python/blob/main/Day_03.02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = int(input("Enter a number: "))

if x % 2 == 0:
  print(f"{x} is even.")
else:
  print(f"{x} is odd.")
# Out:
# Enter a number: 43
# 43 is odd.
