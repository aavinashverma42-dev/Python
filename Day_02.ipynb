# %% [markdown]
# <a href="https://colab.research.google.com/github/aavinashverma42-dev/python-day-01/blob/main/Day_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# datatypes
a: int = 10
b: float = 40.67
c: str = "Avinash"

x,y,z = 10, 20, 30
print(x+y+z)

a, b = 24, 36
c = a + b
print(c)
# Out:
# 60
# 60
