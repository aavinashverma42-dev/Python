# %% [markdown]
# <a href="https://colab.research.google.com/github/aavinashverma42-dev/Python/blob/main/Day_03.01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Conditional statements
# If-Else statement

ticket_price = 400
wallet_size = 400

if(ticket_price <= wallet_size):
  print("Got the ticket to movie!")
else:
  print("I'm low on wallet!")

marks = 85

if(marks >= 90):
  print("Grade A")
elif(marks >= 80):
  print("Grade B")
elif(marks >= 70):
  print("Grade C")
else:
  print("You fails!")
# Out:
# Got the ticket to movie!
# Grade B
